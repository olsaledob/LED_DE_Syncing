# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("E:\Git\CIDBN\SyncingExampleData\Results\\2025-03-17T14-03-49_RecID-587_I24613_KG_poisson025-62p5ms_15moff-15mon-15moff_5p5V_DIV14_HS277_only-de_correction_log.csv")

plt.scatter(df.before_ts, df.linetype, label="Before", alpha=0.4)
plt.scatter(df.after_ts, df.linetype, label="After", alpha=0.4)
plt.xlabel("Timestamp")
plt.ylabel("Linetype")
plt.legend()
plt.show()

# Or find the specific bug:
# bug_df = df[(df.anomaly_type.isnull()) & (df.linetype == cfg.bytes["BYTE_Y"])]
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\G'
# <>:4: SyntaxWarning: invalid escape sequence '\G'
# C:\Users\Laslo\AppData\Local\Temp\ipykernel_9976\1602044446.py:4: SyntaxWarning: invalid escape sequence '\G'
#   df = pd.read_csv("E:\Git\CIDBN\SyncingExampleData\Results\\2025-03-17T14-03-49_RecID-587_I24613_KG_poisson025-62p5ms_15moff-15mon-15moff_5p5V_DIV14_HS277_only-de_correction_log.csv")
